# %% [markdown]
# # 7. Streamlit Data Preparation
#
# This section prepares and validates the final dataset for use in the Streamlit dashboard.

# %%
# Import required libraries

import pandas as pd
import numpy as np

# %%
# Load final processed dataset

df = pd.read_csv("../data/processed/employee_engagement_dataset.csv")

df.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  YearsSinceLastPromotion  YearsWithCurrManager  \
# ...

# %%
# Check final dataset shape

print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Rows: 1470
# Columns: 39

# %%
# Define required dashboard columns

dashboard_columns = [
    "Age",
    "Attrition",
    "Department",
    "JobRole",
    "JobLevel",
    "OverTime",
    "BusinessTravel",
    "DistanceFromHome",
    "JobSatisfaction",
    "EnvironmentSatisfaction",
    "RelationshipSatisfaction",
    "WorkLifeBalance",
    "YearsAtCompany",
    "YearsInCurrentRole",
    "YearsSinceLastPromotion",
    "Engagement_Index",
    "Engagement_Category",
    "Burnout_Risk_Score",
    "Burnout_Risk_Level",
    "Satisfaction_Stability_Score",
    "Workload_Stress_Indicator"
]

# %%
# Check missing values in final dataset

total_missing = df.isnull().sum().sum()

print("Total Missing Values:", total_missing)
# Out:
# Total Missing Values: 0

# %%
# Check duplicate records

print("Duplicate Records:", df.duplicated().sum())
# Out:
# Duplicate Records: 0

# %%
# Check Engagement Index range

print("Minimum Engagement Index:", df["Engagement_Index"].min())
print("Maximum Engagement Index:", df["Engagement_Index"].max())
# Out:
# Minimum Engagement Index: 1.25
# Maximum Engagement Index: 4.0

# %%
# Check burnout risk levels

print(df["Burnout_Risk_Level"].value_counts())
# Out:
# Burnout_Risk_Level
# Low       756
# Medium    588
# High      126
# Name: count, dtype: int64

# %%
# Check engagement categories

print(df["Engagement_Category"].value_counts())
# Out:
# Engagement_Category
# Moderate    814
# High        587
# Low          69
# Name: count, dtype: int64

# %%
# Create dashboard-ready dataset

dashboard_df = df[dashboard_columns].copy()

dashboard_df.head()
# Out:
#    Age  Attrition              Department                JobRole  JobLevel  \
# 0   41          1                   Sales        Sales Executive         2
# 1   49          0  Research & Development     Research Scientist         2
# 2   37          1  Research & Development  Laboratory Technician         1
# 3   33          0  Research & Development     Research Scientist         1
# 4   27          0  Research & Development  Laboratory Technician         1
#
#   OverTime     BusinessTravel  DistanceFromHome  JobSatisfaction  \
# 0      Yes      Travel_Rarely                 1                4
# 1       No  Travel_Frequently                 8                2
# 2      Yes      Travel_Rarely                 2                3
# 3      Yes  Travel_Frequently                 3                3
# 4       No      Travel_Rarely                 2                2
#
#    EnvironmentSatisfaction  ...  WorkLifeBalance  YearsAtCompany  \
# ...

# %%
# Save dashboard-ready dataset

dashboard_path = "../data/processed/dashboard_dataset.csv"

dashboard_df.to_csv(
    dashboard_path,
    index=False
)

print("Dashboard dataset saved successfully.")
print("File:", dashboard_path)
# Out:
# Dashboard dataset saved successfully.
# File: ../data/processed/dashboard_dataset.csv

# %%
# Final dashboard data validation

print("========== DASHBOARD DATA VALIDATION ==========")
print("Rows:", dashboard_df.shape[0])
print("Columns:", dashboard_df.shape[1])
print("Missing Values:", dashboard_df.isnull().sum().sum())
print("Duplicate Rows:", dashboard_df.duplicated().sum())
print("===============================================")
# Out:
# ========== DASHBOARD DATA VALIDATION ==========
# Rows: 1470
# Columns: 21
# Missing Values: 0
# Duplicate Rows: 0
# ...

# %% [markdown]
# ## Observation
#
# The final processed dataset was successfully validated and prepared for the Streamlit dashboard. The dashboard-ready dataset contains the key employee, engagement, burnout, workload, career, and satisfaction variables required for interactive analysis.
